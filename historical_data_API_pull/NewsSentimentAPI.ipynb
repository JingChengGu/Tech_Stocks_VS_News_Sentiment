# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from textblob import TextBlob
import urllib.parse
import time
import os
from dotenv import load_dotenv
import re

from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch 
import torch.nn.functional as F
from tqdm import tqdm
# Out:
# 2025-05-16 23:44:38.192792: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
load_dotenv()
api_key = os.getenv('NEWS_API_KEY')
if not api_key:
    raise ValueError("API key is missing. Set the News_API_KEY environment variable in the .env file.")
tickers = ["Apple", "Google", "Microsoft", "Amazon", "Meta", "Nvidia", "Tesla", "Netflix", "AMD", "Palantir"]
base_url = f"https://newsapi.org/v2/everything?"
sentiment_data = []
news_data = []
call_count = 0

# %%
for i in range(5):
    date = datetime.utcnow() - timedelta(days = i)
    from_date = to_date = date.strftime("%Y-%m-%d")

    for ticker in tickers:
        print(f"Pulling news for {ticker} on {from_date}")
        
        params = {
            "q": f'"{ticker}"',
            "searchIn": "title",
            "from": from_date,
            "to": to_date,
            "language": "en",
            "sortBy": "relevancy",
            "pageSize": 10,
            "apiKey": api_key
        }
        try:
            r = requests.get(base_url, params = params)
            r.raise_for_status()
            articles = r.json().get("articles", [])
        
        except Exception as e:
            print(f"Error fetching data from {ticker} on {from_date}: {e}")
            continue
            
        for article in articles:
            article["ticker"] = ticker
            # getting first 10 character of the timestamp string yyyy-mm-dd
            article["date"] = article.get("publishedAt", "")[:10] 
            news_data.append(article)

        time.sleep(1.1)
# Out:
# Pulling news for Apple on 2025-05-16

# %%
news_df = pd.DataFrame(news_data)
news_df
# Out:
#                                          source  \
# 0      {'id': 'the-verge', 'name': 'The Verge'}
# 1             {'id': None, 'name': 'MacRumors'}
# 2             {'id': None, 'name': 'MacRumors'}
# 3             {'id': None, 'name': 'MacRumors'}
# 4             {'id': None, 'name': 'MacRumors'}
# 5             {'id': None, 'name': 'MacRumors'}
# 6          {'id': None, 'name': 'AppleInsider'}
# 7               {'id': None, 'name': '9to5Mac'}
# 8               {'id': None, 'name': '9to5Mac'}
# 9   {'id': None, 'name': 'Yahoo Entertainment'}
# 10     {'id': 'the-verge', 'name': 'The Verge'}
# 11            {'id': None, 'name': 'MacRumors'}
# 12            {'id': None, 'name': 'MacRumors'}
# 13            {'id': None, 'name': 'MacRumors'}
# 14            {'id': None, 'name': 'MacRumors'}
# 15            {'id': None, 'name': 'MacRumors'}
# 16         {'id': None, 'name': 'AppleInsider'}
# 17              {'id': None, 'name': '9to5Mac'}
# 18              {'id': None, 'name': '9to5Mac'}
# 19  {'id': None, 'name': 'Yahoo Entertainment'}
# 20     {'id': 'the-verge', 'name': 'The Verge'}
# 21            {'id': None, 'name': 'MacRumors'}
# 22            {'id': None, 'name': 'MacRumors'}
# 23            {'id': None, 'name': 'MacRumors'}
# 24            {'id': None, 'name': 'MacRumors'}
# 25            {'id': None, 'name': 'MacRumors'}
# 26         {'id': None, 'name': 'AppleInsider'}
# 27              {'id': None, 'name': '9to5Mac'}
# 28              {'id': None, 'name': '9to5Mac'}
# 29  {'id': None, 'name': 'Yahoo Entertainment'}
# 30     {'id': 'the-verge', 'name': 'The Verge'}
# 31            {'id': None, 'name': 'MacRumors'}
# 32            {'id': None, 'name': 'MacRumors'}
# 33            {'id': None, 'name': 'MacRumors'}
# 34            {'id': None, 'name': 'MacRumors'}
# 35            {'id': None, 'name': 'MacRumors'}
# 36         {'id': None, 'name': 'AppleInsider'}
# 37              {'id': None, 'name': '9to5Mac'}
# 38              {'id': None, 'name': '9to5Mac'}
# 39  {'id': None, 'name': 'Yahoo Entertainment'}
#
#                                     author  \
# 0                         Andrew Liszewski
# 1                              Juli Clover
# 2                        Mitchel Broussard
# 3                              Eric Slivka
# 4                              Juli Clover
# 5                              Juli Clover
# 6   news@appleinsider.com (Marko Zivkovic)
# 7                         Ryan Christoffel
# 8                        Michael Burkhardt
# 9                                     None
# 10                        Andrew Liszewski
# 11                             Juli Clover
# 12                       Mitchel Broussard
# 13                             Eric Slivka
# 14                             Juli Clover
# 15                             Juli Clover
# 16  news@appleinsider.com (Marko Zivkovic)
# 17                        Ryan Christoffel
# 18                       Michael Burkhardt
# 19                                    None
# 20                        Andrew Liszewski
# 21                             Juli Clover
# 22                       Mitchel Broussard
# 23                             Eric Slivka
# 24                             Juli Clover
# 25                             Juli Clover
# 26  news@appleinsider.com (Marko Zivkovic)
# 27                        Ryan Christoffel
# 28                       Michael Burkhardt
# 29                                    None
# 30                        Andrew Liszewski
# 31                             Juli Clover
# 32                       Mitchel Broussard
# 33                             Eric Slivka
# 34                             Juli Clover
# 35                             Juli Clover
# 36  news@appleinsider.com (Marko Zivkovic)
# 37                        Ryan Christoffel
# 38                       Michael Burkhardt
# 39                                    None
#
#                                                 title  \
# 0   Apple Music’s new transfer tool simplifies swi...
# 1   Apple Pay, Apple Card, Wallet and Apple Cash C...
# 2   Best Apple Deals of the Week: Sitewide Sales H...
# 3   Apple Stops Signing iPadOS 17.7.7 After Report...
# 4   Apple Says Fortnite for iOS Isn't Blocked Worl...
# 5   MacRumors Giveaway: Win an Apple Watch Ultra 2...
# 6   Apple Pay and Apple Cash experienced an outage...
# 7   Apple Pay and Apple Cash are down for many iPh...
# 8   Apple News+ is quickly becoming a hidden gem i...
# 9   Lopez v. Apple lawsuit: How you can file a cla...
# 10  Apple Music’s new transfer tool simplifies swi...
# 11  Apple Pay, Apple Card, Wallet and Apple Cash C...
# 12  Best Apple Deals of the Week: Sitewide Sales H...
# 13  Apple Stops Signing iPadOS 17.7.7 After Report...
# 14  Apple Says Fortnite for iOS Isn't Blocked Worl...
# 15  MacRumors Giveaway: Win an Apple Watch Ultra 2...
# 16  Apple Pay and Apple Cash experienced an outage...
# 17  Apple Pay and Apple Cash are down for many iPh...
# 18  Apple News+ is quickly becoming a hidden gem i...
# 19  Lopez v. Apple lawsuit: How you can file a cla...
# 20  Apple Music’s new transfer tool simplifies swi...
# 21  Apple Pay, Apple Card, Wallet and Apple Cash C...
# 22  Best Apple Deals of the Week: Sitewide Sales H...
# 23  Apple Stops Signing iPadOS 17.7.7 After Report...
# 24  Apple Says Fortnite for iOS Isn't Blocked Worl...
# 25  MacRumors Giveaway: Win an Apple Watch Ultra 2...
# 26  Apple Pay and Apple Cash experienced an outage...
# 27  Apple Pay and Apple Cash are down for many iPh...
# 28  Apple News+ is quickly becoming a hidden gem i...
# 29  Lopez v. Apple lawsuit: How you can file a cla...
# 30  Apple Music’s new transfer tool simplifies swi...
# 31  Apple Pay, Apple Card, Wallet and Apple Cash C...
# 32  Best Apple Deals of the Week: Sitewide Sales H...
# 33  Apple Stops Signing iPadOS 17.7.7 After Report...
# 34  Apple Says Fortnite for iOS Isn't Blocked Worl...
# 35  MacRumors Giveaway: Win an Apple Watch Ultra 2...
# 36  Apple Pay and Apple Cash experienced an outage...
# 37  Apple Pay and Apple Cash are down for many iPh...
# 38  Apple News+ is quickly becoming a hidden gem i...
# 39  Lopez v. Apple lawsuit: How you can file a cla...
#
#                                           description  \
# 0   To potentially make it easier for users of str...
# 1   If you're having problems using your Apple Car...
# 2   This week's best deals include a big sitewide ...
# 3   Apple has stopped signing the iPadOS 17.7.7 up...
# 4   Apple today clarified that it has not blocked ...
# 5   For this week's giveaway, we've teamed up with...
# 6   An Apple Pay and Apple Cash problem left users...
# 7   Trying to make a payment using your iPhone? Yo...
# 8   9to5Mac is brought to you by Incogni: Protect ...
# 9                                                None
# 10  To potentially make it easier for users of str...
# 11  If you're having problems using your Apple Car...
# 12  This week's best deals include a big sitewide ...
# 13  Apple has stopped signing the iPadOS 17.7.7 up...
# 14  Apple today clarified that it has not blocked ...
# 15  For this week's giveaway, we've teamed up with...
# 16  An Apple Pay and Apple Cash problem left users...
# 17  Trying to make a payment using your iPhone? Yo...
# 18  9to5Mac is brought to you by Incogni: Protect ...
# 19                                               None
# 20  To potentially make it easier for users of str...
# 21  If you're having problems using your Apple Car...
# 22  This week's best deals include a big sitewide ...
# 23  Apple has stopped signing the iPadOS 17.7.7 up...
# 24  Apple today clarified that it has not blocked ...
# 25  For this week's giveaway, we've teamed up with...
# 26  An Apple Pay and Apple Cash problem left users...
# 27  Trying to make a payment using your iPhone? Yo...
# 28  9to5Mac is brought to you by Incogni: Protect ...
# 29                                               None
# 30  To potentially make it easier for users of str...
# 31  If you're having problems using your Apple Car...
# 32  This week's best deals include a big sitewide ...
# 33  Apple has stopped signing the iPadOS 17.7.7 up...
# 34  Apple today clarified that it has not blocked ...
# 35  For this week's giveaway, we've teamed up with...
# 36  An Apple Pay and Apple Cash problem left users...
# 37  Trying to make a payment using your iPhone? Yo...
# 38  9to5Mac is brought to you by Incogni: Protect ...
# 39                                               None
#
#                                                   url  \
# 0   https://www.theverge.com/news/668369/apple-mus...
# 1   https://www.macrumors.com/2025/05/16/apple-pay...
# 2   https://www.macrumors.com/2025/05/16/best-appl...
# 3   https://www.macrumors.com/2025/05/15/apple-sto...
# 4   https://www.macrumors.com/2025/05/16/apple-for...
# 5   https://www.macrumors.com/2025/05/16/macrumors...
# 6   https://appleinsider.com/articles/25/05/16/app...
# 7   https://9to5mac.com/2025/05/16/apple-pay-and-a...
# 8   https://9to5mac.com/2025/05/16/apple-news-hidd...
# 9   https://consent.yahoo.com/v2/collectConsent?se...
# 10  https://www.theverge.com/news/668369/apple-mus...
# 11  https://www.macrumors.com/2025/05/16/apple-pay...
# 12  https://www.macrumors.com/2025/05/16/best-appl...
# 13  https://www.macrumors.com/2025/05/15/apple-sto...
# 14  https://www.macrumors.com/2025/05/16/apple-for...
# 15  https://www.macrumors.com/2025/05/16/macrumors...
# 16  https://appleinsider.com/articles/25/05/16/app...
# 17  https://9to5mac.com/2025/05/16/apple-pay-and-a...
# 18  https://9to5mac.com/2025/05/16/apple-news-hidd...
# 19  https://consent.yahoo.com/v2/collectConsent?se...
# 20  https://www.theverge.com/news/668369/apple-mus...
# 21  https://www.macrumors.com/2025/05/16/apple-pay...
# 22  https://www.macrumors.com/2025/05/16/best-appl...
# 23  https://www.macrumors.com/2025/05/15/apple-sto...
# 24  https://www.macrumors.com/2025/05/16/apple-for...
# 25  https://www.macrumors.com/2025/05/16/macrumors...
# 26  https://appleinsider.com/articles/25/05/16/app...
# 27  https://9to5mac.com/2025/05/16/apple-pay-and-a...
# 28  https://9to5mac.com/2025/05/16/apple-news-hidd...
# 29  https://consent.yahoo.com/v2/collectConsent?se...
# 30  https://www.theverge.com/news/668369/apple-mus...
# 31  https://www.macrumors.com/2025/05/16/apple-pay...
# 32  https://www.macrumors.com/2025/05/16/best-appl...
# 33  https://www.macrumors.com/2025/05/15/apple-sto...
# 34  https://www.macrumors.com/2025/05/16/apple-for...
# 35  https://www.macrumors.com/2025/05/16/macrumors...
# 36  https://appleinsider.com/articles/25/05/16/app...
# 37  https://9to5mac.com/2025/05/16/apple-pay-and-a...
# 38  https://9to5mac.com/2025/05/16/apple-news-hidd...
# 39  https://consent.yahoo.com/v2/collectConsent?se...
#
#                                            urlToImage           publishedAt  \
# 0   https://platform.theverge.com/wp-content/uploa...  2025-05-16T13:34:21Z
# 1   https://images.macrumors.com/t/RQPLZ_3_iMyj3ev...  2025-05-16T16:45:54Z
# 2   https://images.macrumors.com/t/d77AV3K7FCzvXhA...  2025-05-16T15:10:07Z
# 3   https://images.macrumors.com/t/DoYicdwGvOHw-VK...  2025-05-16T03:08:02Z
# 4   https://images.macrumors.com/t/_WvBzBow0b8ZAmv...  2025-05-16T16:58:29Z
# 5   https://images.macrumors.com/t/tNvNv1VotoF8kNU...  2025-05-16T17:39:56Z
# 6   https://photos5.appleinsider.com/gallery/63659...  2025-05-16T18:43:05Z
# 7   https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T16:32:45Z
# 8   https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T20:30:38Z
# 9                                                None  2025-05-16T18:00:17Z
# 10  https://platform.theverge.com/wp-content/uploa...  2025-05-16T13:34:21Z
# 11  https://images.macrumors.com/t/RQPLZ_3_iMyj3ev...  2025-05-16T16:45:54Z
# 12  https://images.macrumors.com/t/d77AV3K7FCzvXhA...  2025-05-16T15:10:07Z
# 13  https://images.macrumors.com/t/DoYicdwGvOHw-VK...  2025-05-16T03:08:02Z
# 14  https://images.macrumors.com/t/_WvBzBow0b8ZAmv...  2025-05-16T16:58:29Z
# 15  https://images.macrumors.com/t/tNvNv1VotoF8kNU...  2025-05-16T17:39:56Z
# 16  https://photos5.appleinsider.com/gallery/63659...  2025-05-16T18:43:05Z
# 17  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T16:32:45Z
# 18  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T20:30:38Z
# 19                                               None  2025-05-16T18:00:17Z
# 20  https://platform.theverge.com/wp-content/uploa...  2025-05-16T13:34:21Z
# 21  https://images.macrumors.com/t/RQPLZ_3_iMyj3ev...  2025-05-16T16:45:54Z
# 22  https://images.macrumors.com/t/d77AV3K7FCzvXhA...  2025-05-16T15:10:07Z
# 23  https://images.macrumors.com/t/DoYicdwGvOHw-VK...  2025-05-16T03:08:02Z
# 24  https://images.macrumors.com/t/_WvBzBow0b8ZAmv...  2025-05-16T16:58:29Z
# 25  https://images.macrumors.com/t/tNvNv1VotoF8kNU...  2025-05-16T17:39:56Z
# 26  https://photos5.appleinsider.com/gallery/63659...  2025-05-16T18:43:05Z
# 27  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T16:32:45Z
# 28  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T20:30:38Z
# 29                                               None  2025-05-16T18:00:17Z
# 30  https://platform.theverge.com/wp-content/uploa...  2025-05-16T13:34:21Z
# 31  https://images.macrumors.com/t/RQPLZ_3_iMyj3ev...  2025-05-16T16:45:54Z
# 32  https://images.macrumors.com/t/d77AV3K7FCzvXhA...  2025-05-16T15:10:07Z
# 33  https://images.macrumors.com/t/DoYicdwGvOHw-VK...  2025-05-16T03:08:02Z
# 34  https://images.macrumors.com/t/_WvBzBow0b8ZAmv...  2025-05-16T16:58:29Z
# 35  https://images.macrumors.com/t/tNvNv1VotoF8kNU...  2025-05-16T17:39:56Z
# 36  https://photos5.appleinsider.com/gallery/63659...  2025-05-16T18:43:05Z
# 37  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T16:32:45Z
# 38  https://i0.wp.com/9to5mac.com/wp-content/uploa...  2025-05-16T20:30:38Z
# 39                                               None  2025-05-16T18:00:17Z
#
#                                               content ticker        date
# 0   You can transfer songs, albums, and playlists ...  Apple  2025-05-16
# 1   If you're having problems using your Apple Car...  Apple  2025-05-16
# 2   This week's best deals include a big sitewide ...  Apple  2025-05-16
# 3   Apple has stopped signing the iPadOS 17.7.7 up...  Apple  2025-05-16
# 4   Apple today clarified that it has not blocked ...  Apple  2025-05-16
# 5   For this week's giveaway, we've teamed up with...  Apple  2025-05-16
# 6   An Apple Pay and Apple Cash problem left users...  Apple  2025-05-16
# 7   Trying to make a payment using your iPhone? Yo...  Apple  2025-05-16
# 8   9to5Mac is brought to you by Incogni:Protect y...  Apple  2025-05-16
# 9   If you click 'Accept all', we and our partners...  Apple  2025-05-16
# 10  You can transfer songs, albums, and playlists ...  Apple  2025-05-16
# 11  If you're having problems using your Apple Car...  Apple  2025-05-16
# 12  This week's best deals include a big sitewide ...  Apple  2025-05-16
# 13  Apple has stopped signing the iPadOS 17.7.7 up...  Apple  2025-05-16
# 14  Apple today clarified that it has not blocked ...  Apple  2025-05-16
# 15  For this week's giveaway, we've teamed up with...  Apple  2025-05-16
# 16  An Apple Pay and Apple Cash problem left users...  Apple  2025-05-16
# 17  Trying to make a payment using your iPhone? Yo...  Apple  2025-05-16
# 18  9to5Mac is brought to you by Incogni:Protect y...  Apple  2025-05-16
# 19  If you click 'Accept all', we and our partners...  Apple  2025-05-16
# 20  You can transfer songs, albums, and playlists ...  Apple  2025-05-16
# 21  If you're having problems using your Apple Car...  Apple  2025-05-16
# 22  This week's best deals include a big sitewide ...  Apple  2025-05-16
# 23  Apple has stopped signing the iPadOS 17.7.7 up...  Apple  2025-05-16
# 24  Apple today clarified that it has not blocked ...  Apple  2025-05-16
# 25  For this week's giveaway, we've teamed up with...  Apple  2025-05-16
# 26  An Apple Pay and Apple Cash problem left users...  Apple  2025-05-16
# 27  Trying to make a payment using your iPhone? Yo...  Apple  2025-05-16
# 28  9to5Mac is brought to you by Incogni:Protect y...  Apple  2025-05-16
# 29  If you click 'Accept all', we and our partners...  Apple  2025-05-16
# 30  You can transfer songs, albums, and playlists ...  Apple  2025-05-16
# 31  If you're having problems using your Apple Car...  Apple  2025-05-16
# 32  This week's best deals include a big sitewide ...  Apple  2025-05-16
# 33  Apple has stopped signing the iPadOS 17.7.7 up...  Apple  2025-05-16
# 34  Apple today clarified that it has not blocked ...  Apple  2025-05-16
# 35  For this week's giveaway, we've teamed up with...  Apple  2025-05-16
# 36  An Apple Pay and Apple Cash problem left users...  Apple  2025-05-16
# 37  Trying to make a payment using your iPhone? Yo...  Apple  2025-05-16
# 38  9to5Mac is brought to you by Incogni:Protect y...  Apple  2025-05-16
# 39  If you click 'Accept all', we and our partners...  Apple  2025-05-16

# %%
# Only apply this cleanup to 'Apple' ticker
mask = news_df['ticker'] == 'Apple'

fruit_keywords = ['fruit', 'juice', 'pie', 'orchard', 'cider', 'farming', 'produce']

def is_apple_company(row):
    text = (str(row['title']) + ' ' + str(row['description'])).lower()
    return not any(re.search(rf'\b{kw}\b', text) for kw in fruit_keywords)

dropped = news_df[mask].loc[~news_df[mask].apply(is_apple_company, axis=1)]
print("Filtered Apple rows:")
print(dropped[['title', 'description']])

# Filter only Apple rows with the function, keep the rest untouched
news_df = pd.concat([
    news_df[mask].loc[news_df[mask].apply(is_apple_company, axis=1)], # filtered Apple articles
    news_df[~mask]  # non-Apple articles
], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dsc180a/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/envs/dsc180a/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/dsc180a/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ticker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Only apply this cleanup to 'Apple' ticker
# ----> 2 mask = news_df['ticker'] == 'Apple'
#       4 fruit_keywords = ['fruit', 'juice', 'pie', 'orchard', 'cider', 'farming', 'produce']
#       6 def is_apple_company(row):
#
# File /opt/anaconda3/envs/dsc180a/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/anaconda3/envs/dsc180a/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'ticker'

# %%
news_df

# %%
news_df['source'] = news_df['source'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# %%
news_df = news_df[['ticker', 'date', 'source', 'title',	'description', 'url', 'content']]

# %%
news_df
# Out:
#        ticker        date            source  \
# 0       Apple  2025-05-15         The Verge
# 1       Apple  2025-05-15         The Verge
# 2       Apple  2025-05-15         MacRumors
# 3       Apple  2025-05-15         MacRumors
# 4       Apple  2025-05-15  Business Insider
# ..        ...         ...               ...
# 393  Palantir  2025-05-12        Biztoc.com
# 394  Palantir  2025-05-12        Biztoc.com
# 395  Palantir  2025-05-12        Biztoc.com
# 396  Palantir  2025-05-12        Biztoc.com
# 397  Palantir  2025-05-12        Biztoc.com
#
#                                                  title  \
# 0    Trump wants Apple to stop making more iPhones ...
# 1    Apple is placing warnings on EU apps that don’...
# 2    Apple Says These Vehicle Brands Plan to Offer ...
# 3    Apple Highlights Magnifier on Mac and iPhone M...
# 4    Watch out, Apple. ChatGPT and Chipotle have jo...
# ..                                                 ...
# 393  Palantir Stock Targets A Breakout — But Don't ...
# 394  Is Palantir Stock a Buy, Sell, or Hold on New ...
# 395  Wynn Resorts, Microsoft, Palantir And A Health...
# 396  Palantir Technologies (NASDAQ: PLTR) Price Pre...
# 397  Wynn Resorts, Microsoft, Palantir And A Health...
#
#                                            description  \
# 0    President Donald Trump told Apple CEO Tim Cook...
# 1    Apple is trying to dissuade Europeans from usi...
# 2    Apple today announced the launch of CarPlay Ul...
# 3    Apple today shared new videos that highlight t...
# 4    Topping the list for the fourth year in a row ...
# ..                                                 ...
# 393
# 394
# 395  Zinger Key Points\n- Kevin Simpson says Palant...
# 396  Shares of Palantir Technologies Inc. (NASDAQ: ...
# 397  On CNBC's “Halftime Report Final Trades,” Bren...
#
#                                                    url  \
# 0    https://www.theverge.com/news/667649/donald-tr...
# 1    https://www.theverge.com/news/667484/apple-eu-...
# 2    https://www.macrumors.com/2025/05/15/carplay-u...
# 3    https://www.macrumors.com/2025/05/15/apple-vid...
# 4    https://www.businessinsider.com/most-valuable-...
# ..                                                 ...
# 393              https://biztoc.com/x/2a7f9d2be811e31b
# 394              https://biztoc.com/x/dd3f63da1c541d5b
# 395              https://biztoc.com/x/a49d695b302e47de
# 396              https://biztoc.com/x/506a94877b211287
# 397              https://biztoc.com/x/100d76474285849a
#
#                                                content
# 0    Were not interested in you building in India.\...
# 1    Apple suggests that users are putting themselv...
# 2    Apple today announced the launch of CarPlay Ul...
# 3    Apple today shared new videos that highlight t...
# 4    Apple ranked No. 1 on Kantar BrandZ's annual m...
# ..                                                 ...
# 393  { window.open(this.href, '_blank'); }, 200); r...
# 394  { window.open(this.href, '_blank'); }, 200); r...
# 395  Zinger Key Points- Kevin Simpson says Palantir...
# 396  Shares of Palantir Technologies Inc. (NASDAQ: ...
# 397  On CNBC's Halftime Report Final Trades, Brenda...
#
# [398 rows x 7 columns]

# %%
news_df = news_df.dropna(subset = ['description'])

# %%
#news_df = pd.DataFrame(news_data)
print(f'The size of the dataframe: {len(news_df)}')
news_df.isna().sum()
# Out:
# The size of the dataframe: 345
# ticker         0
# date           0
# source         0
# title          0
# description    0
# url            0
# content        0
# dtype: int64

# %%
news_df.to_csv("assets/news_data.csv", index = False)

# %% [markdown]
# ### Sentiment Analysis using FinBERT

# %%
# Load FinBERT model
tokenizer = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")
model = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone")

# %%
def get_finbert_scores_batch(text_list):
    scores = []

    for text in text_list:
        if not text or not text.strip():
            scores.append(None)
            continue

        try:
            # Tokenize with truncation
            inputs = tokenizer(
                text,
                return_tensors="pt",
                truncation=True,
                max_length=512,
                padding=True
            )

            # Force CPU (avoid MPS crash)
            inputs = {k: v.cpu() for k, v in inputs.items()}
            model.cpu()

            with torch.no_grad():
                outputs = model(**inputs)
                logits = outputs.logits
                probs = F.softmax(logits, dim=1).squeeze()

                # Weighted score: +1*pos, -1*neg, 0*neutral
                score = probs[0].item() * 1 + probs[1].item() * -1
                scores.append(score)

        except Exception as e:
            print(f"Error on text: {e}")
            scores.append(None)

    return scores

# %%
news_df['text'] = news_df['title'].fillna('') + ' ' + news_df['description'].fillna('')
sentiments = []

# Batch size: adjust lower if crash continues
batch_size = 16
text_list = news_df['text'].tolist()

for i in tqdm(range(0, len(text_list), batch_size)):
    batch = text_list[i:i+batch_size]
    scores = get_finbert_scores_batch(batch)
    sentiments.extend(scores)

news_df['sentiment'] = sentiments
# Out:
# /var/folders/54/hwsm49bs033bpdy18h8fnp2h0000gn/T/ipykernel_2262/4167040519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df['text'] = news_df['title'].fillna('') + ' ' + news_df['description'].fillna('')
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:23<00:00,  1.05s/it]
# /var/folders/54/hwsm49bs033bpdy18h8fnp2h0000gn/T/ipykernel_2262/4167040519.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df['sentiment'] = sentiments

# %%
news_df
# Out:
#        ticker        date            source  \
# 0       Apple  2025-05-15         The Verge
# 1       Apple  2025-05-15         The Verge
# 2       Apple  2025-05-15         MacRumors
# 3       Apple  2025-05-15         MacRumors
# 4       Apple  2025-05-15  Business Insider
# ..        ...         ...               ...
# 393  Palantir  2025-05-12        Biztoc.com
# 394  Palantir  2025-05-12        Biztoc.com
# 395  Palantir  2025-05-12        Biztoc.com
# 396  Palantir  2025-05-12        Biztoc.com
# 397  Palantir  2025-05-12        Biztoc.com
#
#                                                  title  \
# 0    Trump wants Apple to stop making more iPhones ...
# 1    Apple is placing warnings on EU apps that don’...
# 2    Apple Says These Vehicle Brands Plan to Offer ...
# 3    Apple Highlights Magnifier on Mac and iPhone M...
# 4    Watch out, Apple. ChatGPT and Chipotle have jo...
# ..                                                 ...
# 393  Palantir Stock Targets A Breakout — But Don't ...
# 394  Is Palantir Stock a Buy, Sell, or Hold on New ...
# 395  Wynn Resorts, Microsoft, Palantir And A Health...
# 396  Palantir Technologies (NASDAQ: PLTR) Price Pre...
# 397  Wynn Resorts, Microsoft, Palantir And A Health...
#
#                                            description  \
# 0    President Donald Trump told Apple CEO Tim Cook...
# 1    Apple is trying to dissuade Europeans from usi...
# 2    Apple today announced the launch of CarPlay Ul...
# 3    Apple today shared new videos that highlight t...
# 4    Topping the list for the fourth year in a row ...
# ..                                                 ...
# 393
# 394
# 395  Zinger Key Points\n- Kevin Simpson says Palant...
# 396  Shares of Palantir Technologies Inc. (NASDAQ: ...
# 397  On CNBC's “Halftime Report Final Trades,” Bren...
#
#                                                    url  \
# 0    https://www.theverge.com/news/667649/donald-tr...
# 1    https://www.theverge.com/news/667484/apple-eu-...
# 2    https://www.macrumors.com/2025/05/15/carplay-u...
# 3    https://www.macrumors.com/2025/05/15/apple-vid...
# 4    https://www.businessinsider.com/most-valuable-...
# ..                                                 ...
# 393              https://biztoc.com/x/2a7f9d2be811e31b
# 394              https://biztoc.com/x/dd3f63da1c541d5b
# 395              https://biztoc.com/x/a49d695b302e47de
# 396              https://biztoc.com/x/506a94877b211287
# 397              https://biztoc.com/x/100d76474285849a
#
#                                                content  \
# 0    Were not interested in you building in India.\...
# 1    Apple suggests that users are putting themselv...
# 2    Apple today announced the launch of CarPlay Ul...
# 3    Apple today shared new videos that highlight t...
# 4    Apple ranked No. 1 on Kantar BrandZ's annual m...
# ..                                                 ...
# 393  { window.open(this.href, '_blank'); }, 200); r...
# 394  { window.open(this.href, '_blank'); }, 200); r...
# 395  Zinger Key Points- Kevin Simpson says Palantir...
# 396  Shares of Palantir Technologies Inc. (NASDAQ: ...
# 397  On CNBC's Halftime Report Final Trades, Brenda...
#
#                                                   text  sentiment
# 0    Trump wants Apple to stop making more iPhones ...   0.852582
# 1    Apple is placing warnings on EU apps that don’...   0.034329
# 2    Apple Says These Vehicle Brands Plan to Offer ...   0.992835
# 3    Apple Highlights Magnifier on Mac and iPhone M...   0.977094
# 4    Watch out, Apple. ChatGPT and Chipotle have jo...   0.900195
# ..                                                 ...        ...
# 393  Palantir Stock Targets A Breakout — But Don't ...   0.999448
# 394  Is Palantir Stock a Buy, Sell, or Hold on New ...   0.923462
# 395  Wynn Resorts, Microsoft, Palantir And A Health...  -0.999932
# 396  Palantir Technologies (NASDAQ: PLTR) Price Pre...   0.400149
# 397  Wynn Resorts, Microsoft, Palantir And A Health...   0.999925
#
# [345 rows x 9 columns]

# %%
news_df.to_csv("assets/news_data.csv", index = False)

# %%
sentiment_data = []
grouped = news_df.groupby(['ticker', 'date'])
for (ticker, date), group in grouped:
    article_count = group['sentiment'].count()
    avg_sentiment = group['sentiment'].mean()

    sentiment_data.append({
        "ticker": ticker,
        "date": date,
        "article_count": article_count,
        "avg_sentiment": avg_sentiment
    })

# %%
sentiment_df = pd.DataFrame(sentiment_data)
sentiment_df
# Out:
#        ticker        date  article_count  avg_sentiment
# 0         AMD  2025-05-12             10       0.198285
# 1         AMD  2025-05-13              9       0.384438
# 2         AMD  2025-05-14              8       0.153094
# 3         AMD  2025-05-15              8       0.381166
# 4      Amazon  2025-05-12             10      -0.015021
# 5      Amazon  2025-05-13             10       0.541110
# 6      Amazon  2025-05-14             10       0.426235
# 7      Amazon  2025-05-15             10       0.226408
# 8       Apple  2025-05-12              9       0.996728
# 9       Apple  2025-05-13             10       0.448320
# 10      Apple  2025-05-14             10       0.612171
# 11      Apple  2025-05-15              9       0.804477
# 12     Google  2025-05-12             10       0.938281
# 13     Google  2025-05-13             10       0.635129
# 14     Google  2025-05-14             10      -0.050720
# 15     Google  2025-05-15             10       0.399396
# 16       Meta  2025-05-12              8       0.233929
# 17       Meta  2025-05-13             10       0.413308
# 18       Meta  2025-05-14              8       0.863031
# 19       Meta  2025-05-15             10       0.311078
# 20  Microsoft  2025-05-12              9       0.554412
# 21  Microsoft  2025-05-13             10       0.344745
# 22  Microsoft  2025-05-14              9       0.599050
# 23  Microsoft  2025-05-15             10       0.412742
# 24    Netflix  2025-05-12              9       0.555735
# 25    Netflix  2025-05-13              9       0.391192
# 26    Netflix  2025-05-14             10       0.763205
# 27    Netflix  2025-05-15             10       0.567253
# 28     Nvidia  2025-05-12              8       0.178526
# 29     Nvidia  2025-05-13              4      -0.440682
# 30     Nvidia  2025-05-14              8       0.065210
# 31     Nvidia  2025-05-15              7       0.202190
# 32   Palantir  2025-05-12              8       0.165380
# 33   Palantir  2025-05-13              2      -0.999969
# 34   Palantir  2025-05-14              6       0.231922
# 35   Palantir  2025-05-15              9      -0.278482
# 36      Tesla  2025-05-12              6       0.400121
# 37      Tesla  2025-05-13              6       0.191843
# 38      Tesla  2025-05-14              8       0.395696
# 39      Tesla  2025-05-15              8       0.626514

# %%
sentiment_df['avg_sentiment'] = sentiment_df['avg_sentiment'].round(3)

# %%
sentiment_df
# Out:
#        ticker        date  article_count  avg_sentiment
# 0         AMD  2025-05-12             10          0.198
# 1         AMD  2025-05-13              9          0.384
# 2         AMD  2025-05-14              8          0.153
# 3         AMD  2025-05-15              8          0.381
# 4      Amazon  2025-05-12             10         -0.015
# 5      Amazon  2025-05-13             10          0.541
# 6      Amazon  2025-05-14             10          0.426
# 7      Amazon  2025-05-15             10          0.226
# 8       Apple  2025-05-12              9          0.997
# 9       Apple  2025-05-13             10          0.448
# 10      Apple  2025-05-14             10          0.612
# 11      Apple  2025-05-15              9          0.804
# 12     Google  2025-05-12             10          0.938
# 13     Google  2025-05-13             10          0.635
# 14     Google  2025-05-14             10         -0.051
# 15     Google  2025-05-15             10          0.399
# 16       Meta  2025-05-12              8          0.234
# 17       Meta  2025-05-13             10          0.413
# 18       Meta  2025-05-14              8          0.863
# 19       Meta  2025-05-15             10          0.311
# 20  Microsoft  2025-05-12              9          0.554
# 21  Microsoft  2025-05-13             10          0.345
# 22  Microsoft  2025-05-14              9          0.599
# 23  Microsoft  2025-05-15             10          0.413
# 24    Netflix  2025-05-12              9          0.556
# 25    Netflix  2025-05-13              9          0.391
# 26    Netflix  2025-05-14             10          0.763
# 27    Netflix  2025-05-15             10          0.567
# 28     Nvidia  2025-05-12              8          0.179
# 29     Nvidia  2025-05-13              4         -0.441
# 30     Nvidia  2025-05-14              8          0.065
# 31     Nvidia  2025-05-15              7          0.202
# 32   Palantir  2025-05-12              8          0.165
# 33   Palantir  2025-05-13              2         -1.000
# 34   Palantir  2025-05-14              6          0.232
# 35   Palantir  2025-05-15              9         -0.278
# 36      Tesla  2025-05-12              6          0.400
# 37      Tesla  2025-05-13              6          0.192
# 38      Tesla  2025-05-14              8          0.396
# 39      Tesla  2025-05-15              8          0.627

# %%
sentiment_df.to_csv("assets/news_sentiment.csv", index = False)

# %%
news_df.isna().sum()
# Out:
# ticker         0
# date           0
# source         0
# title          0
# description    0
# url            0
# content        0
# text           0
# sentiment      0
# dtype: int64
